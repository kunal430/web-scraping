# %% [markdown]
# web scraping with pandas

# %%
#importing liabraries
import pandas as pd

# %%
#getting the data from a link
#putting that data in a veriable
data=pd.read_html('https://en.wikipedia.org/wiki/List_of_Hindi_films_of_2024')

# %%
# getting the no. data frame
len(data)
# Out:
# 9

# %%
#getting the data frame using index no.
data[1]
# Out:
#    Rank[a]                             Title  \
# 0        1                           Stree 2
# 1        2                 Bhool Bhulaiyaa 3
# 2        3                     Singham Again
# 3        4                           Fighter
# 4        5                          Shaitaan
# 5        6                              Crew
# 6        7  Teri Baaton Mein Aisa Uljha Jiya
# 7        8                            Munjya
# 8        9                          Bad Newz
# 9       10                       Article 370
#
#                                   Production Company  \
# 0                           Maddock FilmsJio Studios
# 1                        T-Series FilmsCine1 Studios
# 2  Reliance EntertainmentJio StudiosRohit Shetty ...
# 3                   Viacom18 StudiosMarflix Pictures
# 4             Jio StudiosDevgn FilmsPanorama Studios
# 5  Balaji Motion PicturesAnil Kapoor Films & Comm...
# 6                           Maddock FilmsJio Studios
# ...

# %%
#got this data frame at the 1 location
#that shows the list of highest-grossing Hindi cinema films released in 2024.

# %%
data[2]
# Out:
#    Opening  Opening.1                             Title  \
# 0    J A N        5.0                  Tauba Tera Jalwa
# 1    J A N       12.0                Merry Christmas[e]
# 2    J A N       19.0                    Main Atal Hoon
# 3    J A N       25.0                           Fighter
# 4    F E B        NaN                               NaN
# 5    F E B        9.0  Teri Baaton Mein Aisa Uljha Jiya
# 6    F E B        9.0                          Bhakshak
# 7    F E B        9.0                          Lantrani
# 8    F E B        9.0                              Mirg
# 9    F E B       16.0                            Dashmi
# 10   F E B       16.0              Kuch Khattaa Ho Jaay
# 11   F E B       23.0                             Crakk
# 12   F E B       23.0                       Article 370
# 13   F E B       23.0                    All India Rank
# 14   F E B       23.0                       Chote Nawab
# 15   M A R        1.0                   Laapataa Ladies
# ...

# %%
#got this data frame at the 2 location
#that shows the list of Hindi cinema films released in jan to mar 2024.

# %%
data[3]
# Out:
#    Opening  Opening.1                                  Title  \
# 0    A P R        5.0                                 Dukaan
# 1    A P R       11.0                 Bade Miyan Chote Miyan
# 2    A P R       11.0                                Maidaan
# 3    A P R       12.0                    Amar Singh Chamkila
# 4    A P R       12.0                                 Ameena
# 5    A P R       12.0                          Gauraiya Live
# 6    A P R       16.0  Silence 2: The Night Owl Bar Shootout
# 7    A P R       19.0                  Love Sex Aur Dhokha 2
# 8    A P R       19.0                        Do Aur Do Pyaar
# 9    A P R       19.0                         Kaam Chalu Hai
# 10   A P R       19.0                                   Appu
# 11   A P R       19.0                        Luv You Shankar
# 12   A P R       19.0                The Legacy of Jineshwar
# 13   A P R       26.0                                Ruslaan
# ...

# %%
#got this data frame at the 3 location
#that shows the list of Hindi cinema films released in apr to jun 2024.

# %%
data[4]
# Out:
#    Opening  Opening.1                           Title            Director  \
# 0    J U L        5.0                            Kill  Nikhil Nagesh Bhat
# 1    J U L       10.0                Wild Wild Punjab    Simarpreet Singh
# 2    J U L       12.0                         Sarfira       Sudha Kongara
# 3    J U L       12.0                          Kakuda    Aditya Sarpotdar
# 4    J U L       19.0                        Bad Newz        Anand Tiwari
# 5    J U L       19.0  Accident or Conspiracy: Godhra       M.K Shivaaksh
# 6    J U L       26.0                     Bloody Ishq        Vikram Bhatt
# 7    J U L       26.0                           Pride     Pankaj Kr Virat
# 8    A U G        2.0        Auron Mein Kahan Dum Tha       Neeraj Pandey
# 9    A U G        2.0                           Ulajh     Sudhanshu Saria
# 10   A U G        9.0            Aliya Basu Gayab Hai        Preeti Singh
# 11   A U G        9.0      Phir Aayi Hasseen Dillruba       Jayprad Desai
# ...

# %%
#got this data frame at the 4 location
#that shows the list of Hindi cinema films released in jul to sep 2024.

# %%
data[5]
# Out:
#    Opening  Opening.1                          Title              Director  \
# 0    O C T        4.0                           CTRL  Vikramaditya Motwane
# 1    O C T        4.0       Amar Prem Ki Prem Kahani         Hardik Gajjar
# 2    O C T        4.0                  The Signature        Gajendra Ahire
# 3    O C T       11.0                          Jigra            Vasan Bala
# 4    O C T       11.0  Vicky Vidya Ka Woh Wala Video      Raaj Shaandilyaa
# 5    O C T       18.0   Aayushmati Geeta Matric Pass      Prradip Khairwar
# 6    O C T       25.0                       Do Patti  Shashanka Chaturvedi
# 7    O C T       25.0         Bandaa Singh Chaudhary       Abhishek Saxena
# 8    O C T       25.0           The Miranda Brothers          Sanjay Gupta
# 9    O C T       25.0           Navras Katha Collage      Praveen Hingonia
# 10   N O V        1.0              Bhool Bhulaiyaa 3          Anees Bazmee
# ...

# %%
#got this data frame at the 5 location
#that shows the list of Hindi cinema films released in oct to dec 2024.
